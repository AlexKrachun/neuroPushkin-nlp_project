# %% [markdown]
# ## выбираю размер словаря и делаю токенайзер

# %%
from collections import Counter
import matplotlib.pyplot as plt

from tqdm.auto import tqdm

from pymystem3 import Mystem

from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

import re

# %% [markdown]
# ## отчищу данные от разметочных символов для токенизации

# %%
paths =['dataset/generated/generated_pushkin.txt', 'dataset/generated/generated_curious_pushkin.txt']
paths_clean = ['tokenizer/dataset/generated_pushkin.txt', 'tokenizer/dataset/generated_curious_pushkin.txt']
for i in range(len(paths)):
    f =  open(paths[i], 'r', encoding='utf-8')
    text = f.read().lower()
    f.close()
    
    f = open(paths_clean[i], 'w', encoding='utf-8')
    cleaned_text = re.sub(r'[^а-яА-Я\s.,!?;:\-—\'"«»()…]', '', text)
    print(cleaned_text, file=f)
    f.close()

# %%
def draw_tokens_frequency(paths, vocab_size=1000, ylim=200, k=10, dataset_name='сгенерированном/оригинальном'):
    
    tokenizer = Tokenizer(BPE(unk_token='<unk>'))
    trainer = BpeTrainer(vocab_size=vocab_size, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>', '<\n>'])
    tokenizer.pre_tokenizer = Whitespace()
    tokenizer.train(paths, trainer)

    tokens = []
    for path in paths:
        with open(path, 'r', encoding='utf-8') as f:
            tokens += tokenizer.encode(f.read()).tokens


    print(f'всего токенов: {len(tokens)}')
    print(f'среди них уникальных {len(set(tokens))}')
    
    counter = Counter(tokens)
    words_cou = sorted(i[1] for i in counter.items())
    
    ind_k = -1
    for i, v in enumerate(words_cou):
        if v >= k:
            ind_k = i
            break
            
    
    
    plt.figure(figsize=(16, 9))
    plt.ylim((0, ylim))
    plt.xlim((0, len(words_cou)))
    
    plt.plot(words_cou, linewidth=2, label='частотное распределение токенов')
    
    
    plt.axvline(x=ind_k, linestyle='--', color='purple', linewidth=2, alpha=0.3)
    plt.axhline(y=words_cou[ind_k], linestyle='--', color='purple', linewidth=2, alpha=0.3)
    
    
    plt.scatter(ind_k, words_cou[ind_k], color='r', s=100, zorder=5)
    
    plt.xlabel('количество токенов')
    plt.ylabel('частота токенов')
    
    
    
    plt.title(f'Размер словаря: {vocab_size}. В {dataset_name} датасете не менее {k} раз встречается {len(words_cou) - ind_k} ~ {(len(words_cou) - ind_k) / len(words_cou) * 100:.2f}% токенов')
    plt.legend()
    plt.show()

# %%
paths = ['tokenizer/dataset/generated_pushkin.txt', 'tokenizer/dataset/generated_curious_pushkin.txt']

# %%
for vocab_size in range(200, 5_000, 500):
    draw_tokens_frequency(paths=paths, vocab_size=vocab_size, ylim=100_000, k=1_000, dataset_name='сгенерированном')
# Out:
# всего токенов: 10898582
# среди них уникальных 194
# всего токенов: 8166449
# среди них уникальных 692
# всего токенов: 7274878
# среди них уникальных 1191
# всего токенов: 6785347
# среди них уникальных 1691
# всего токенов: 6454264
# среди них уникальных 2191
# всего токенов: 6209070
# среди них уникальных 2690
# всего токенов: 6018611
# среди них уникальных 3190
# всего токенов: 5864278
# среди них уникальных 3689
# всего токенов: 5736671
# среди них уникальных 4189
# всего токенов: 5628133
# среди них уникальных 4689

# %% [markdown]
# ## каким должен быть размер словаря?

# %% [markdown]
# 1. достаточно большим, чтобы модель могла генерировать разнообразные тексты и не переобучалась
# 2. не слишком большим (основная масса токено встречалась 1000+ раз), чтобы модель выучилась

# %% [markdown]
# подберу оптимальный размер:

# %%
for vocab_size in range(1300, 1700, 100):
    draw_tokens_frequency(paths=paths, vocab_size=vocab_size, ylim=10_000, k=1_000, dataset_name='сгенерированном')
# Out:
# всего токенов: 7157130
# среди них уникальных 1291
# всего токенов: 7050354
# среди них уникальных 1391
# всего токенов: 6953394
# среди них уникальных 1491
# всего токенов: 6865555
# среди них уникальных 1591

# %% [markdown]
# довольно не плохие графики на размерах 1300-1500. Для того, чтобы лучше выбрать, нарисую график зависимости процента токенов 1000+ встречаний от размера словаря

# %%
paths = [
    'dataset/generated/generated_pushkin.txt',
    'dataset/generated/generated_curious_pushkin.txt',
    # 'dataset/pushkin/cleaned.txt'
]

vocab_sizes = []
perc = []
for s in tqdm(range(1300, 1500, 5)):
    vocab_sizes.append(s)

    tokenizer = Tokenizer(BPE(unk_token='<unk>'))
    trainer = BpeTrainer(vocab_size=s, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>', '<\n>'])
    tokenizer.pre_tokenizer = Whitespace()
    tokenizer.train(paths, trainer)



    
    tokens = []
    for path in paths:
        with open(path, 'r', encoding='utf-8') as f:
            tokens += tokenizer.encode(f.read()).tokens

    counter = Counter(tokens)
    words_cou = sorted(i[1] for i in counter.items())
    
    ind_1000 = -1
    for i, v in enumerate(words_cou):
        if v >= 1000:
            ind_1000 = i
            break

    perc.append((len(words_cou) - ind_1000) / len(words_cou) * 100)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# Cell In[38], line 22
#      20 tokens = []
#      21 for path in paths:
# ---> 22     with open(path, 'r', encoding='utf-8') as f:
#      23         tokens += tokenizer.encode(f.read()).tokens
#      25 counter = Counter(tokens)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(16, 9))
plt.plot(vocab_sizes, perc)
plt.title('процент токенов 1000+ встречаний в зависимотси от размера словаря')
plt.grid(True)
plt.xticks([i for i in range(1300, 1500, 20)])

plt.show()

# %% [markdown]
# видно, что окрестность 1420 - самый удачный размер с точки зрения выбора частоты токенов и увеличения размера словаря, тк с посел 1420 резко падает частота токенов в тексте, а до 1420 частота значительно не меняется, за то размер алфавита уменьшается, что не хорошо

# %% [markdown]
# мой выбор - словарь размером 1420 токенов

# %% [markdown]
#  ## пора делать токенизатор

# %%
paths = [
    'dataset/generated/generated_pushkin.txt',
    'dataset/generated/generated_curious_pushkin.txt',
    # 'dataset/pushkin/cleaned.txt'
]

tokenizer = Tokenizer(BPE(unk_token='<unk>'))
trainer = BpeTrainer(vocab_size=1420, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>', '<\n>'])
tokenizer.pre_tokenizer = Whitespace()
tokenizer.train(paths, trainer)
tokenizer.save('tokenizer/tokenizer_2_vocab_1420_made_on_generated_data')

# %%
draw_tokens_frequency(paths=paths, vocab_size=1420, ylim=8_000, k=1_000, dataset_name='сгенерированном')
# Out:
# всего токенов: 7030237
# среди них уникальных 1411
