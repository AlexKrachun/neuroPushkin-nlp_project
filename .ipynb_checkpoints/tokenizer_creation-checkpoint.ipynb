# %% [markdown]
# ## выбираю размер словаря и делаю токенайзер

# %%
from collections import Counter
import matplotlib.pyplot as plt

from tqdm import tqdm

from pymystem3 import Mystem

from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
def draw_tokens_frequency(paths, vocab_size=1000, ylim=200, k=10, dataset_name='сгенерированном/оригинальном'):
    
    tokenizer = Tokenizer(BPE(unk_token='<unk>'))
    trainer = BpeTrainer(vocab_size=vocab_size, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>'])
    tokenizer.pre_tokenizer = Whitespace()
    tokenizer.train(paths, trainer)

    tokens = []
    for path in paths:
        with open(path, 'r', encoding='utf-8') as f:
            tokens += tokenizer.encode(f.read()).tokens


    print(f'всего токенов: {len(tokens)}')
    print(f'среди них уникальных {len(set(tokens))}')
    
    counter = Counter(tokens)
    words_cou = sorted(i[1] for i in counter.items())
    
    ind_k = -1
    for i, v in enumerate(words_cou):
        if v >= k:
            ind_k = i
            break
            
    
    
    plt.figure(figsize=(16, 9))
    plt.ylim((0, ylim))
    plt.xlim((0, len(words_cou)))
    
    plt.plot(words_cou, linewidth=2, label='частотное распределение токенов')
    
    
    plt.axvline(x=ind_k, linestyle='--', color='purple', linewidth=2, alpha=0.3)
    plt.axhline(y=words_cou[ind_k], linestyle='--', color='purple', linewidth=2, alpha=0.3)
    
    
    plt.scatter(ind_k, words_cou[ind_k], color='r', s=100, zorder=5)
    
    plt.xlabel('количество токенов')
    plt.ylabel('частота токенов')
    
    
    
    plt.title(f'Размер словаря: {vocab_size}. В {dataset_name} датасете не менее {k} раз встречается {len(words_cou) - ind_k} ~ {(len(words_cou) - ind_k) / len(words_cou) * 100:.2f}% токенов')
    plt.legend()
    plt.show()

# %%
paths = [
    'dataset/generated/generated_pushkin.txt',
    'dataset/generated/generated_curious_pushkin.txt',
    'dataset/pushkin/cleaned.txt'
]

# %%
for vocab_size in range(200, 5_000, 500):
    draw_tokens_frequency(paths=paths, vocab_size=vocab_size, ylim=100_000, k=1_000, dataset_name='сгенерированном')
# Out:
# всего токенов: 16291553
# среди них уникальных 195
# всего токенов: 11457124
# среди них уникальных 693
# всего токенов: 10201334
# среди них уникальных 1193
# всего токенов: 9517929
# среди них уникальных 1693
# всего токенов: 9067095
# среди них уникальных 2193
# всего токенов: 8731902
# среди них уникальных 2693
# всего токенов: 8465712
# среди них уникальных 3192
# всего токенов: 8249766
# среди них уникальных 3692
# всего токенов: 8069449
# среди них уникальных 4192
# всего токенов: 7917017
# среди них уникальных 4692

# %% [markdown]
# ## каким должен быть размер словаря?

# %% [markdown]
# 1. достаточно большим, чтобы модель могла генерировать разнообразные тексты и не переобучалась
# 2. не слишком большим (основная масса токено встречалась 1000+ раз), чтобы модель выучилась

# %% [markdown]
# подберу оптимальный размер:

# %%
for vocab_size in range(1_500, 2_200, 100):
    draw_tokens_frequency(paths=paths, vocab_size=vocab_size, ylim=100_000, k=1_000, dataset_name='сгенерированном')
# Out:
# всего токенов: 9753643
# среди них уникальных 1493
# всего токенов: 9630250
# среди них уникальных 1593
# всего токенов: 9517929
# среди них уникальных 1693
# всего токенов: 9413836
# среди них уникальных 1793
# всего токенов: 9317928
# среди них уникальных 1893
# всего токенов: 9228325
# среди них уникальных 1993
# всего токенов: 9144523
# среди них уникальных 2093

# %% [markdown]
# довольно не плохие графики на размерах 1700-1900. Для того, чтобы лучше выбрать, нарисую график зависимости процента токенов 1000+ встречаний от размера словаря

# %%
paths = [
    'dataset/generated/generated_pushkin.txt',
    'dataset/generated/generated_curious_pushkin.txt',
    'dataset/pushkin/cleaned.txt'
]

vocab_sizes = []
perc = []
for s in tqdm(range(1700, 1900, 10), desc=''):
    vocab_sizes.append(s)

    tokenizer = Tokenizer(BPE(unk_token='<unk>'))
    trainer = BpeTrainer(vocab_size=s, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>'])
    tokenizer.pre_tokenizer = Whitespace()
    tokenizer.train(paths, trainer)



    
    tokens = []
    for path in paths:
        with open(path, 'r', encoding='utf-8') as f:
            tokens += tokenizer.encode(f.read()).tokens

    counter = Counter(tokens)
    words_cou = sorted(i[1] for i in counter.items())
    
    ind_1000 = -1
    for i, v in enumerate(words_cou):
        if v >= 1000:
            ind_1000 = i
            break

    perc.append((len(words_cou) - ind_1000) / len(words_cou) * 100)
# Out:
#   0%|                                               | 0/20 [00:00<?, ?it/s]
#   5%|█▉                                     | 1/20 [00:15<04:50, 15.30s/it]
#  10%|███▉                                   | 2/20 [00:30<04:36, 15.35s/it]
#  15%|█████▊                                 | 3/20 [00:45<04:19, 15.27s/it]
#  20%|███████▊                               | 4/20 [01:01<04:04, 15.27s/it]
#  25%|█████████▊                             | 5/20 [01:16<03:49, 15.32s/it]
#  30%|███████████▋                           | 6/20 [01:31<03:34, 15.32s/it]
#  35%|█████████████▋                         | 7/20 [01:47<03:19, 15.33s/it]
#  40%|███████████████▌                       | 8/20 [02:02<03:03, 15.33s/it]
#  45%|█████████████████▌                     | 9/20 [02:17<02:48, 15.34s/it]
#  50%|███████████████████                   | 10/20 [02:33<02:33, 15.31s/it]
#  55%|████████████████████▉                 | 11/20 [02:48<02:17, 15.31s/it]
#  60%|██████████████████████▊               | 12/20 [03:03<02:02, 15.31s/it]
#  65%|████████████████████████▋             | 13/20 [03:19<01:47, 15.32s/it]
#  70%|██████████████████████████▌           | 14/20 [03:34<01:31, 15.31s/it]
#  75%|████████████████████████████▌         | 15/20 [03:49<01:16, 15.28s/it]
#  80%|██████████████████████████████▍       | 16/20 [04:04<01:01, 15.28s/it]
#  85%|████████████████████████████████▎     | 17/20 [04:20<00:45, 15.31s/it]
#  90%|██████████████████████████████████▏   | 18/20 [04:35<00:30, 15.31s/it]
#  95%|████████████████████████████████████  | 19/20 [04:50<00:15, 15.33s/it]
# 100%|██████████████████████████████████████| 20/20 [05:06<00:00, 15.31s/it]

# %%
plt.figure(figsize=(16, 9))
plt.plot(vocab_sizes, perc)
plt.title('процент токенов 1000+ встречаний в зависимотси от размера словаря')
plt.grid(True)
plt.xticks([i for i in range(1700, 1900, 10)])

plt.show()

# %% [markdown]
# видно, что окрестность 1790 - самый удачный размер с точки зрения выбора частоты токенов и увеличения размера словаря, тк с посел 1790 реско падает частота токенов в тексте, а до 1790 частота не меняется, за то размер алфавита уменьшается, что тоже не хорошо

# %% [markdown]
# мой выбор - словарь размером 1790 токенов

# %% [markdown]
#  ## пора делать токенизатор

# %%
paths = [
    'dataset/generated/generated_pushkin.txt',
    'dataset/generated/generated_curious_pushkin.txt',
    'dataset/pushkin/cleaned.txt'
]

tokenizer = Tokenizer(BPE(unk_token='<unk>'))
trainer = BpeTrainer(vocab_size=s, min_frequency=100, special_tokens=['<unk>', '<bos>', '<eos>', '<pad>'])
tokenizer.pre_tokenizer = Whitespace()
tokenizer.train(paths, trainer)
tokenizer.save('tokenizer/tokenizer_1_vocab_1790')
